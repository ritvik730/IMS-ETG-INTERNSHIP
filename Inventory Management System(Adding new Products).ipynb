# %%
import json

# %% [markdown]
# # Read Data from JSON

# %%
fd = open("records.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1': {'ProductID': 1001,
#   'Product name': 'Haldiram Bhujia',
#   'Price': 30,
#   'In stock items': 100,
#   'Expiry date': 'Nov 2021'},
#  '2': {'ProductID': 1002,
#   'Product name': 'Haldiram Channa',
#   'Price': 35,
#   'In stock items': 90,
#   'Expiry date': 'Nov 2021'},
#  '3': {'ProductID': 1003,
#   'Product name': 'Bicano Bhujia',
#   'Price': 25,
#   'In stock items': 100,
#   'Expiry date': 'Nov 2021'},
#  '4': {'ProductID': 1004,
#   'Product name': 'Bicano Channa',
#   'Price': 30,
#   'In stock items': 80,
#   'Expiry date': 'Nov 2021'},
#  '5': {'ProductID': 1005,
#   'Product name': 'Bourbon Biscuits',
#   'Price': 20,
#   'In stock items': 80,
#   'Expiry date': 'Oct 2021'},
#  '6': {'ProductID': 1006,
#   'Product name': 'Oreo Biscuits',
#   'Price': 30,
#   'In stock items': 100,
#   'Expiry date': 'Oct 2021'},
#  '7': {'ProductID': 1007,
#   'Product name': 'Good Day Biscuits',
#   'Price': 20,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2021'},
#  '8': {'ProductID': 1008,
#   'Product name': 'Oatmeal Biscuits',
#   'Price': 50,
#   'In stock items': 90,
#   'Expiry date': 'Dec 2021'},
#  '9': {'ProductID': 1009,
#   'Product name': 'Raisins Packet',
#   'Price': 200,
#   'In stock items': 500,
#   'Expiry date': 'Oct 2023'},
#  '10': {'ProductID': 1010,
#   'Product name': 'Mixed Fruit jam',
#   'Price': 135,
#   'In stock items': 90,
#   'Expiry date': 'Apr 2022'},
#  '11': {'ProductID': 1011,
#   'Product name': 'Mango Jam',
#   'Price': 130,
#   'In stock items': 100,
#   'Expiry date': 'Apr 2022'},
#  '12': {'ProductID': 1012,
#   'Product name': 'Blueberry Jam',
#   'Price': 160,
#   'In stock items': 50,
#   'Expiry date': 'Apr 2022'},
#  '13': {'ProductID': 1013,
#   'Product name': 'Maggi Noodles',
#   'Price': 40,
#   'In stock items': 500,
#   'Expiry date': 'Oct 2022'},
#  '14': {'ProductID': 1014,
#   'Product name': 'Schezwan Chutney',
#   'Price': 15,
#   'In stock items': 100,
#   'Expiry date': 'Dec 2021'},
#  '15': {'ProductID': 1015,
#   'Product name': 'Chings Noodles',
#   'Price': 20,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2021'},
#  '16': {'ProductID': 1016,
#   'Product name': 'Saffola Oats',
#   'Price': 120,
#   'In stock items': 90,
#   'Expiry date': 'Dec 2021'},
#  '17': {'ProductID': 1017,
#   'Product name': 'Saffola Oodles',
#   'Price': 50,
#   'In stock items': 50,
#   'Expiry date': 'Oct 2022'},
#  '18': {'ProductID': 1018,
#   'Product name': 'Kelloggs Oats',
#   'Price': 75,
#   'In stock items': 90,
#   'Expiry date': 'Nov 2021'},
#  '19': {'ProductID': 1019,
#   'Product name': 'Kelloggs Muesli',
#   'Price': 200,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2022'},
#  '20': {'ProductID': 1020,
#   'Product name': 'Peanut Butter',
#   'Price': 160,
#   'In stock items': 80,
#   'Expiry date': 'Nov 2021'},
#  '21': {'ProductID': 1021,
#   'Product name': 'Dry Fruits',
#   'Price': 500,
#   'In stock items': 120,
#   'Expiry date': 'Oct 2023'},
#  '22': {'ProductID': 1022,
#   'Product name': 'Henz Ketchup',
#   'Price': 30,
#   'In stock items': 100,
#   'Expiry date': 'Oct 2021'},
#  '23': {'ProductID': 1023,
#   'Product name': 'Kissan Ketchup',
#   'Price': 15,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2021'},
#  '24': {'ProductID': 1024,
#   'Product name': 'Maggi Ketchup',
#   'Price': 30,
#   'In stock items': 90,
#   'Expiry date': 'Dec 2021'},
#  '25': {'ProductID': 1025,
#   'Product name': 'Toothbrush',
#   'Price': 20,
#   'In stock items': 100,
#   'Expiry date': 'Oct 2023'},
#  '26': {'ProductID': 1026,
#   'Product name': 'Toothpaste',
#   'Price': 90,
#   'In stock items': 90,
#   'Expiry date': 'Apr 2022'},
#  '27': {'ProductID': 1027,
#   'Product name': 'Mortein refil',
#   'Price': 100,
#   'In stock items': 100,
#   'Expiry date': 'Apr 2022'},
#  '28': {'ProductID': 1028,
#   'Product name': 'Hit Spray ',
#   'Price': 100,
#   'In stock items': 50,
#   'Expiry date': 'Apr 2022'},
#  '29': {'ProductID': 1029,
#   'Product name': 'Odomos paste',
#   'Price': 40,
#   'In stock items': 20,
#   'Expiry date': 'Oct 2022'},
#  '30': {'ProductID': 1030,
#   'Product name': 'Mortein Coil',
#   'Price': 30,
#   'In stock items': 60,
#   'Expiry date': 'Dec 2021'}}

# %% [markdown]
# # Add New Item into Inventory

# %%
num=input("Enter product number")
ID = str(input("Enter product id:"))
name = str(input("Enter product name:"))
pr = int(input("Enter price:"))
qn = int(input("Enter quantity:"))

record[num] = {'ProductID':ID,'Product name': name, 'pr': pr, 'qn': qn}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product number31
# Enter product id:1031
# Enter product name:Navratan mix
# Enter price:70
# Enter quantity:80

# %%
record
# Out:
# {'1': {'ProductID': 1001,
#   'Product name': 'Haldiram Bhujia',
#   'Price': 30,
#   'In stock items': 100,
#   'Expiry date': 'Nov 2021'},
#  '2': {'ProductID': 1002,
#   'Product name': 'Haldiram Channa',
#   'Price': 35,
#   'In stock items': 90,
#   'Expiry date': 'Nov 2021'},
#  '3': {'ProductID': 1003,
#   'Product name': 'Bicano Bhujia',
#   'Price': 25,
#   'In stock items': 100,
#   'Expiry date': 'Nov 2021'},
#  '4': {'ProductID': 1004,
#   'Product name': 'Bicano Channa',
#   'Price': 30,
#   'In stock items': 80,
#   'Expiry date': 'Nov 2021'},
#  '5': {'ProductID': 1005,
#   'Product name': 'Bourbon Biscuits',
#   'Price': 20,
#   'In stock items': 80,
#   'Expiry date': 'Oct 2021'},
#  '6': {'ProductID': 1006,
#   'Product name': 'Oreo Biscuits',
#   'Price': 30,
#   'In stock items': 100,
#   'Expiry date': 'Oct 2021'},
#  '7': {'ProductID': 1007,
#   'Product name': 'Good Day Biscuits',
#   'Price': 20,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2021'},
#  '8': {'ProductID': 1008,
#   'Product name': 'Oatmeal Biscuits',
#   'Price': 50,
#   'In stock items': 90,
#   'Expiry date': 'Dec 2021'},
#  '9': {'ProductID': 1009,
#   'Product name': 'Raisins Packet',
#   'Price': 200,
#   'In stock items': 500,
#   'Expiry date': 'Oct 2023'},
#  '10': {'ProductID': 1010,
#   'Product name': 'Mixed Fruit jam',
#   'Price': 135,
#   'In stock items': 90,
#   'Expiry date': 'Apr 2022'},
#  '11': {'ProductID': 1011,
#   'Product name': 'Mango Jam',
#   'Price': 130,
#   'In stock items': 100,
#   'Expiry date': 'Apr 2022'},
#  '12': {'ProductID': 1012,
#   'Product name': 'Blueberry Jam',
#   'Price': 160,
#   'In stock items': 50,
#   'Expiry date': 'Apr 2022'},
#  '13': {'ProductID': 1013,
#   'Product name': 'Maggi Noodles',
#   'Price': 40,
#   'In stock items': 500,
#   'Expiry date': 'Oct 2022'},
#  '14': {'ProductID': 1014,
#   'Product name': 'Schezwan Chutney',
#   'Price': 15,
#   'In stock items': 100,
#   'Expiry date': 'Dec 2021'},
#  '15': {'ProductID': 1015,
#   'Product name': 'Chings Noodles',
#   'Price': 20,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2021'},
#  '16': {'ProductID': 1016,
#   'Product name': 'Saffola Oats',
#   'Price': 120,
#   'In stock items': 90,
#   'Expiry date': 'Dec 2021'},
#  '17': {'ProductID': 1017,
#   'Product name': 'Saffola Oodles',
#   'Price': 50,
#   'In stock items': 50,
#   'Expiry date': 'Oct 2022'},
#  '18': {'ProductID': 1018,
#   'Product name': 'Kelloggs Oats',
#   'Price': 75,
#   'In stock items': 90,
#   'Expiry date': 'Nov 2021'},
#  '19': {'ProductID': 1019,
#   'Product name': 'Kelloggs Muesli',
#   'Price': 200,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2022'},
#  '20': {'ProductID': 1020,
#   'Product name': 'Peanut Butter',
#   'Price': 160,
#   'In stock items': 80,
#   'Expiry date': 'Nov 2021'},
#  '21': {'ProductID': 1021,
#   'Product name': 'Dry Fruits',
#   'Price': 500,
#   'In stock items': 120,
#   'Expiry date': 'Oct 2023'},
#  '22': {'ProductID': 1022,
#   'Product name': 'Henz Ketchup',
#   'Price': 30,
#   'In stock items': 100,
#   'Expiry date': 'Oct 2021'},
#  '23': {'ProductID': 1023,
#   'Product name': 'Kissan Ketchup',
#   'Price': 15,
#   'In stock items': 70,
#   'Expiry date': 'Nov 2021'},
#  '24': {'ProductID': 1024,
#   'Product name': 'Maggi Ketchup',
#   'Price': 30,
#   'In stock items': 90,
#   'Expiry date': 'Dec 2021'},
#  '25': {'ProductID': 1025,
#   'Product name': 'Toothbrush',
#   'Price': 20,
#   'In stock items': 100,
#   'Expiry date': 'Oct 2023'},
#  '26': {'ProductID': 1026,
#   'Product name': 'Toothpaste',
#   'Price': 90,
#   'In stock items': 90,
#   'Expiry date': 'Apr 2022'},
#  '27': {'ProductID': 1027,
#   'Product name': 'Mortein refil',
#   'Price': 100,
#   'In stock items': 100,
#   'Expiry date': 'Apr 2022'},
#  '28': {'ProductID': 1028,
#   'Product name': 'Hit Spray ',
#   'Price': 100,
#   'In stock items': 50,
#   'Expiry date': 'Apr 2022'},
#  '29': {'ProductID': 1029,
#   'Product name': 'Odomos paste',
#   'Price': 40,
#   'In stock items': 20,
#   'Expiry date': 'Oct 2022'},
#  '30': {'ProductID': 1030,
#   'Product name': 'Mortein Coil',
#   'Price': 30,
#   'In stock items': 60,
#   'Expiry date': 'Dec 2021'},
#  '31': {'ProductID': '1031',
#   'Product name': 'Navratan mix',
#   'pr': 70,
#   'qn': 80}}
